# %%
import pyphi
from visualize_pyphi import *
from visualize_pyphi import utils
import pickle as pkl
from tqdm.auto import tqdm
from pyphi.models.subsystem import FlatCauseEffectStructure as sep
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %%
>>> pyphi.config.load_file('pyphi_config.yml')

# %%
>>> print(pyphi.config)
# Out:
# { 'ACTUAL_CAUSATION_MEASURE': 'PMI',
#   'ASSUME_CUTS_CANNOT_CREATE_NEW_CONCEPTS': False,
#   'CACHE_POTENTIAL_PURVIEWS': True,
#   'CACHE_REPERTOIRES': True,
#   'CACHE_SIAS': False,
#   'CACHING_BACKEND': 'fs',
#   'CES_DISTANCE': 'SUM_SMALL_PHI',
#   'CLEAR_SUBSYSTEM_CACHES_AFTER_COMPUTING_SIA': False,
#   'CUT_ONE_APPROXIMATION': False,
#   'FS_CACHE_DIRECTORY': '__pyphi_cache__',
#   'FS_CACHE_VERBOSITY': 0,
#   'IIT_VERSION': 'maximal-state-first',
#   'LOG_FILE': 'pyphi.log',
#   'LOG_FILE_LEVEL': 'INFO',
#   'LOG_STDOUT_LEVEL': 'WARNING',
#   'MAXIMUM_CACHE_MEMORY_PERCENTAGE': 100,
#   'MONGODB_CONFIG': { 'collection_name': 'test',
#                       'database_name': 'pyphi',
#                       'host': 'localhost',
#                       'port': 27017},
#   'NUMBER_OF_CORES': -1,
#   'PARALLEL_COMPLEX_EVALUATION': False,
#   'PARALLEL_CONCEPT_EVALUATION': False,
#   'PARALLEL_CUT_EVALUATION': False,
#   'PARTITION_TYPE': 'TRI',
#   'PICK_SMALLEST_PURVIEW': False,
#   'PRECISION': 15,
#   'PRINT_FRACTIONS': True,
#   'PROGRESS_BARS': True,
#   'RAY_CONFIG': {'address': 'auto'},
#   'REDIS_CACHE': False,
#   'REDIS_CONFIG': {'db': 0, 'host': 'localhost', 'port': 6379, 'test_db': 1},
#   'REPERTOIRE_DISTANCE': 'IIT_4.0_SMALL_PHI',
#   'REPR_VERBOSITY': 2,
#   'SINGLE_MICRO_NODES_WITH_SELFLOOPS_HAVE_PHI': False,
#   'SYSTEM_CUTS': '3.0_STYLE',
#   'VALIDATE_CONDITIONAL_INDEPENDENCE': True,
#   'VALIDATE_SUBSYSTEM_STATES': True,
#   'WELCOME_OFF': True}

# %%
'''
Check that the config parameters are correct (if not change pyphi_config.yml to match):
REPERTOIRE_DISTANCE = 'IIT_4.0_SMALL_PHI'
IIT_VERSION = 'maximal-state-first'
PARTITION_TYPE = 'TRI'
'''
pyphi.config.REPERTOIRE_DISTANCE,pyphi.config.IIT_VERSION,pyphi.config.PARTITION_TYPE
# Out:
# ('IIT_4.0_SMALL_PHI', 'maximal-state-first', 'TRI')

# %%
with open(r"example_data/4_node_grid_subsystem.pkl", "rb") as f:
    subsystem = pkl.load(f)

# %%
#Compute all distinctions
distinctions = pyphi.compute.ces(subsystem)

# %%
distinctions
# Out:
# ════════════════════════════════════════════════════════════════════════
#                   Cause-effect structure (15 concepts)
# ════════════════════════════════════════════════════════════════════════
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#     Concept: mechanism = [A], state = [0], φ = 0.520382
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#               MIC                         MIE
#   ┌──────────────────────────┐┌──────────────────────────┐
#   │  φ = 0.520382            ││  φ = 0.656129            │
#   │  Purview: [A]            ││  Purview: [A]            │
#   │  MIP:                    ││  MIP:                    │
#   │     ∅     ∅     A        ││     ∅     ∅     A        │
#   │    ─── ✕ ─── ✕ ───       ││    ─── ✕ ─── ✕ ───       │
#   │     ∅     A     ∅        ││     ∅     A     ∅        │
#   │  Repertoire:             ││  Repertoire:             │
#   │    ┌────────────────┐    ││    ┌─────────────────┐   │
#   │    │ S    Pr(S)     │    ││    │ S    Pr(S)      │   │
#   │    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │    ││    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │   │
#   │    │ 0 *  0.789544  │    ││    │ 0 *  0.995506   │   │
#   │    │ 1    0.210456  │    ││    │ 1    0.0044943  │   │
#   │    └────────────────┘    ││    └─────────────────┘   │
#   │  Partitioned repertoire: ││  Partitioned repertoire: │
#   │    ┌─────────────┐       ││    ┌────────────────┐    │
#   │    │ S    Pr(S)  │       ││    │ S    Pr(S)     │    │
#   │    │ ╴╴╴╴╴╴╴╴╴╴╴ │       ││    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │    │
#   │    │ 0 *  1/2    │       ││    │ 0 *  0.630431  │    │
#   │    │ 1    1/2    │       ││    │ 1    0.369569  │    │
#   │    └─────────────┘       ││    └────────────────┘    │
#   └──────────────────────────┘└──────────────────────────┘
#
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#     Concept: mechanism = [B], state = [0], φ = 0.629285
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#               MIC                         MIE
#   ┌──────────────────────────┐┌──────────────────────────┐
#   │  φ = 0.629285            ││  φ = 0.713724            │
#   │  Purview: [B]            ││  Purview: [B]            │
#   │  MIP:                    ││  MIP:                    │
#   │     ∅     ∅     B        ││     ∅     ∅     B        │
#   │    ─── ✕ ─── ✕ ───       ││    ─── ✕ ─── ✕ ───       │
#   │     ∅     B     ∅        ││     ∅     B     ∅        │
#   │  Repertoire:             ││  Repertoire:             │
#   │    ┌────────────────┐    ││    ┌─────────────────┐   │
#   │    │ S    Pr(S)     │    ││    │ S    Pr(S)      │   │
#   │    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │    ││    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │   │
#   │    │ 0 *  0.840264  │    ││    │ 0 *  0.953012   │   │
#   │    │ 1    0.159736  │    ││    │ 1    0.0469881  │   │
#   │    └────────────────┘    ││    └─────────────────┘   │
#   │  Partitioned repertoire: ││  Partitioned repertoire: │
#   │    ┌─────────────┐       ││    ┌────────────────┐    │
#   │    │ S    Pr(S)  │       ││    │ S    Pr(S)     │    │
#   │    │ ╴╴╴╴╴╴╴╴╴╴╴ │       ││    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │    │
#   │    │ 0 *  1/2    │       ││    │ 0 *  0.567091  │    │
#   │    │ 1    1/2    │       ││    │ 1    0.432909  │    │
#   │    └─────────────┘       ││    └────────────────┘    │
#   └──────────────────────────┘└──────────────────────────┘
#
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#     Concept: mechanism = [C], state = [0], φ = 0.629285
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#               MIC                         MIE
#   ┌──────────────────────────┐┌──────────────────────────┐
#   │  φ = 0.629285            ││  φ = 0.713724            │
#   │  Purview: [C]            ││  Purview: [C]            │
#   │  MIP:                    ││  MIP:                    │
#   │     ∅     ∅     C        ││     ∅     ∅     C        │
#   │    ─── ✕ ─── ✕ ───       ││    ─── ✕ ─── ✕ ───       │
#   │     ∅     C     ∅        ││     ∅     C     ∅        │
#   │  Repertoire:             ││  Repertoire:             │
#   │    ┌────────────────┐    ││    ┌─────────────────┐   │
#   │    │ S    Pr(S)     │    ││    │ S    Pr(S)      │   │
#   │    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │    ││    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │   │
#   │    │ 0 *  0.840264  │    ││    │ 0 *  0.953012   │   │
#   │    │ 1    0.159736  │    ││    │ 1    0.0469881  │   │
#   │    └────────────────┘    ││    └─────────────────┘   │
#   │  Partitioned repertoire: ││  Partitioned repertoire: │
#   │    ┌─────────────┐       ││    ┌────────────────┐    │
#   │    │ S    Pr(S)  │       ││    │ S    Pr(S)     │    │
#   │    │ ╴╴╴╴╴╴╴╴╴╴╴ │       ││    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │    │
#   │    │ 0 *  1/2    │       ││    │ 0 *  0.567091  │    │
#   │    │ 1    1/2    │       ││    │ 1    0.432909  │    │
#   │    └─────────────┘       ││    └────────────────┘    │
#   └──────────────────────────┘└──────────────────────────┘
#
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#     Concept: mechanism = [D], state = [0], φ = 0.520382
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#               MIC                         MIE
#   ┌──────────────────────────┐┌──────────────────────────┐
#   │  φ = 0.520382            ││  φ = 0.656129            │
#   │  Purview: [D]            ││  Purview: [D]            │
#   │  MIP:                    ││  MIP:                    │
#   │     ∅     ∅     D        ││     ∅     ∅     D        │
#   │    ─── ✕ ─── ✕ ───       ││    ─── ✕ ─── ✕ ───       │
#   │     ∅     D     ∅        ││     ∅     D     ∅        │
#   │  Repertoire:             ││  Repertoire:             │
#   │    ┌────────────────┐    ││    ┌─────────────────┐   │
#   │    │ S    Pr(S)     │    ││    │ S    Pr(S)      │   │
#   │    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │    ││    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │   │
#   │    │ 0 *  0.789544  │    ││    │ 0 *  0.995506   │   │
#   │    │ 1    0.210456  │    ││    │ 1    0.0044943  │   │
#   │    └────────────────┘    ││    └─────────────────┘   │
#   │  Partitioned repertoire: ││  Partitioned repertoire: │
#   │    ┌─────────────┐       ││    ┌────────────────┐    │
#   │    │ S    Pr(S)  │       ││    │ S    Pr(S)     │    │
#   │    │ ╴╴╴╴╴╴╴╴╴╴╴ │       ││    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │    │
#   │    │ 0 *  1/2    │       ││    │ 0 *  0.630431  │    │
#   │    │ 1    1/2    │       ││    │ 1    0.369569  │    │
#   │    └─────────────┘       ││    └────────────────┘    │
#   └──────────────────────────┘└──────────────────────────┘
#
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Concept: mechanism = [A,B], state = [0, 0], φ = 0.0691195
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#               MIC                          MIE
#   ┌──────────────────────────┐┌───────────────────────────┐
#   │  φ = 0.0714848           ││  φ = 0.0691195            │
#   │  Purview: [A,B]          ││  Purview: [A,B]           │
#   │  MIP:                    ││  MIP:                     │
#   │     ∅     A     B        ││     ∅     A     B         │
#   │    ─── ✕ ─── ✕ ───       ││    ─── ✕ ─── ✕ ───        │
#   │     ∅     A     B        ││     ∅     A     B         │
#   │  Repertoire:             ││  Repertoire:              │
#   │    ┌───────────────────┐ ││    ┌────────────────────┐ │
#   │    │ S     Pr(S)       │ ││    │ S     Pr(S)        │ │
#   │    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │ ││    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │ │
#   │    │ 00 *  0.611814    │ ││    │ 00 *  0.995504     │ │
#   │    │ 10    0.218177    │ ││    │ 10    1.54821e-06  │ │
#   │    │ 01    0.161616    │ ││    │ 01    0.00449429   │ │
#   │    │ 11    0.00839352  │ ││    │ 11    6.98951e-09  │ │
#   │    └───────────────────┘ ││    └────────────────────┘ │
#   │  Partitioned repertoire: ││  Partitioned repertoire:  │
#   │    ┌──────────────────┐  ││    ┌────────────────────┐ │
#   │    │ S     Pr(S)      │  ││    │ S     Pr(S)        │ │
#   │    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │  ││    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │ │
#   │    │ 00 *  0.663425   │  ││    │ 00 *  0.948729     │ │
#   │    │ 10    0.176839   │  ││    │ 10    0.00428312   │ │
#   │    │ 01    0.126119   │  ││    │ 01    0.0467769    │ │
#   │    │ 11    0.0336175  │  ││    │ 11    0.000211179  │ │
#   │    └──────────────────┘  ││    └────────────────────┘ │
#   └──────────────────────────┘└───────────────────────────┘
#
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Concept: mechanism = [A,C], state = [0, 0], φ = 0.0752189
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#               MIC                          MIE
#   ┌──────────────────────────┐┌────────────────────────────┐
#   │  φ = 0.0752189           ││  φ = 0.10776               │
#   │  Purview: [B]            ││  Purview: [A,B,C]          │
#   │  MIP:                    ││  MIP:                      │
#   │     ∅     A     C        ││     ∅     A     C          │
#   │    ─── ✕ ─── ✕ ───       ││    ─── ✕ ─── ✕ ───         │
#   │     ∅     ∅     B        ││     ∅    A,B    C          │
#   │  Repertoire:             ││  Repertoire:               │
#   │    ┌────────────────┐    ││    ┌─────────────────────┐ │
#   │    │ S    Pr(S)     │    ││    │  S     Pr(S)        │ │
#   │    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │    ││    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │ │
#   │    │ 0 *  0.605803  │    ││    │ 000 *  0.668781     │ │
#   │    │ 1    0.394197  │    ││    │ 100    0.00158544   │ │
#   │    └────────────────┘    ││    │ 010    0.293571     │ │
#   │  Partitioned repertoire: ││    │ 110    0.000695951  │ │
#   │    ┌────────────────┐    ││    │ 001    0.0245196    │ │
#   │    │ S    Pr(S)     │    ││    │ 101    5.81273e-05  │ │
#   │    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │    ││    │ 011    0.0107632    │ │
#   │    │ 0 *  0.555846  │    ││    │ 111    2.55158e-05  │ │
#   │    │ 1    0.444154  │    ││    └─────────────────────┘ │
#   │    └────────────────┘    ││  Partitioned repertoire:   │
#   └──────────────────────────┘│    ┌─────────────────────┐ │
#                               │    │  S     Pr(S)        │ │
#                               │    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │ │
#                               │    │ 000 *  0.598108     │ │
#                               │    │ 100    0.00270021   │ │
#                               │    │ 010    0.350621     │ │
#                               │    │ 110    0.00158291   │ │
#                               │    │ 001    0.0294896    │ │
#                               │    │ 101    0.000133133  │ │
#                               │    │ 011    0.0172873    │ │
#                               │    │ 111    7.80451e-05  │ │
#                               │    └─────────────────────┘ │
#                               └────────────────────────────┘
#
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Concept: mechanism = [A,D], state = [0, 0], φ = 0.0257269
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#               MIC                         MIE
#   ┌──────────────────────────┐┌──────────────────────────┐
#   │  φ = 0.0257269           ││  φ = 0.030082            │
#   │  Purview: [B,C]          ││  Purview: [B,C]          │
#   │  MIP:                    ││  MIP:                    │
#   │     ∅     A     D        ││     ∅     A     D        │
#   │    ─── ✕ ─── ✕ ───       ││    ─── ✕ ─── ✕ ───       │
#   │     ∅     B     C        ││     ∅     B     C        │
#   │  Repertoire:             ││  Repertoire:             │
#   │    ┌─────────────────┐   ││    ┌─────────────────┐   │
#   │    │ S     Pr(S)     │   ││    │ S     Pr(S)     │   │
#   │    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │   ││    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │   │
#   │    │ 00 *  0.321131  │   ││    │ 00 *  0.417782  │   │
#   │    │ 10    0.242891  │   ││    │ 10    0.228578  │   │
#   │    │ 01    0.242891  │   ││    │ 01    0.228578  │   │
#   │    │ 11    0.193086  │   ││    │ 11    0.125061  │   │
#   │    └─────────────────┘   ││    └─────────────────┘   │
#   │  Partitioned repertoire: ││  Partitioned repertoire: │
#   │    ┌─────────────────┐   ││    ┌─────────────────┐   │
#   │    │ S     Pr(S)     │   ││    │ S     Pr(S)     │   │
#   │    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │   ││    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │   │
#   │    │ 00 *  0.303785  │   ││    │ 00 *  0.397443  │   │
#   │    │ 10    0.247382  │   ││    │ 10    0.232988  │   │
#   │    │ 01    0.247382  │   ││    │ 01    0.232988  │   │
#   │    │ 11    0.201451  │   ││    │ 11    0.136581  │   │
#   │    └─────────────────┘   ││    └─────────────────┘   │
#   └──────────────────────────┘└──────────────────────────┘
#
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Concept: mechanism = [B,C], state = [0, 0], φ = 0.0534277
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#               MIC                          MIE
#   ┌──────────────────────────┐┌───────────────────────────┐
#   │  φ = 0.0534277           ││  φ = 0.124742             │
#   │  Purview: [B,C]          ││  Purview: [B,C]           │
#   │  MIP:                    ││  MIP:                     │
#   │     ∅     B     C        ││     ∅     B     C         │
#   │    ─── ✕ ─── ✕ ───       ││    ─── ✕ ─── ✕ ───        │
#   │     ∅     B     C        ││     ∅     B     C         │
#   │  Repertoire:             ││  Repertoire:              │
#   │    ┌───────────────────┐ ││    ┌────────────────────┐ │
#   │    │ S     Pr(S)       │ ││    │ S     Pr(S)        │ │
#   │    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │ ││    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │ │
#   │    │ 00 *  0.667964    │ ││    │ 00 *  0.991032     │ │
#   │    │ 10    0.162848    │ ││    │ 10    0.0044741    │ │
#   │    │ 01    0.162848    │ ││    │ 01    0.0044741    │ │
#   │    │ 11    0.00633968  │ ││    │ 11    2.01987e-05  │ │
#   │    └───────────────────┘ ││    └────────────────────┘ │
#   │  Partitioned repertoire: ││  Partitioned repertoire:  │
#   │    ┌──────────────────┐  ││    ┌───────────────────┐  │
#   │    │ S     Pr(S)      │  ││    │ S     Pr(S)       │  │
#   │    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │  ││    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │  │
#   │    │ 00 *  0.706043   │  ││    │ 00 *  0.908232    │  │
#   │    │ 10    0.134221   │  ││    │ 10    0.0447802   │  │
#   │    │ 01    0.134221   │  ││    │ 01    0.0447802   │  │
#   │    │ 11    0.0255157  │  ││    │ 11    0.00220788  │  │
#   │    └──────────────────┘  ││    └───────────────────┘  │
#   └──────────────────────────┘└───────────────────────────┘
#
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Concept: mechanism = [B,D], state = [0, 0], φ = 0.0752189
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#               MIC                          MIE
#   ┌──────────────────────────┐┌────────────────────────────┐
#   │  φ = 0.0752189           ││  φ = 0.10776               │
#   │  Purview: [C]            ││  Purview: [B,C,D]          │
#   │  MIP:                    ││  MIP:                      │
#   │     ∅     B     D        ││     ∅     B     D          │
#   │    ─── ✕ ─── ✕ ───       ││    ─── ✕ ─── ✕ ───         │
#   │     ∅     C     ∅        ││     ∅    B,C    D          │
#   │  Repertoire:             ││  Repertoire:               │
#   │    ┌────────────────┐    ││    ┌─────────────────────┐ │
#   │    │ S    Pr(S)     │    ││    │  S     Pr(S)        │ │
#   │    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │    ││    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │ │
#   │    │ 0 *  0.605803  │    ││    │ 000 *  0.668781     │ │
#   │    │ 1    0.394197  │    ││    │ 100    0.0245196    │ │
#   │    └────────────────┘    ││    │ 010    0.293571     │ │
#   │  Partitioned repertoire: ││    │ 110    0.0107632    │ │
#   │    ┌────────────────┐    ││    │ 001    0.00158544   │ │
#   │    │ S    Pr(S)     │    ││    │ 101    5.81273e-05  │ │
#   │    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │    ││    │ 011    0.000695951  │ │
#   │    │ 0 *  0.555846  │    ││    │ 111    2.55158e-05  │ │
#   │    │ 1    0.444154  │    ││    └─────────────────────┘ │
#   │    └────────────────┘    ││  Partitioned repertoire:   │
#   └──────────────────────────┘│    ┌─────────────────────┐ │
#                               │    │  S     Pr(S)        │ │
#                               │    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │ │
#                               │    │ 000 *  0.598108     │ │
#                               │    │ 100    0.0294896    │ │
#                               │    │ 010    0.350621     │ │
#                               │    │ 110    0.0172873    │ │
#                               │    │ 001    0.00270021   │ │
#                               │    │ 101    0.000133133  │ │
#                               │    │ 011    0.00158291   │ │
#                               │    │ 111    7.80451e-05  │ │
#                               │    └─────────────────────┘ │
#                               └────────────────────────────┘
#
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Concept: mechanism = [C,D], state = [0, 0], φ = 0.0691195
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#               MIC                          MIE
#   ┌──────────────────────────┐┌───────────────────────────┐
#   │  φ = 0.0714848           ││  φ = 0.0691195            │
#   │  Purview: [C,D]          ││  Purview: [C,D]           │
#   │  MIP:                    ││  MIP:                     │
#   │     ∅     C     D        ││     ∅     C     D         │
#   │    ─── ✕ ─── ✕ ───       ││    ─── ✕ ─── ✕ ───        │
#   │     ∅     C     D        ││     ∅     C     D         │
#   │  Repertoire:             ││  Repertoire:              │
#   │    ┌───────────────────┐ ││    ┌────────────────────┐ │
#   │    │ S     Pr(S)       │ ││    │ S     Pr(S)        │ │
#   │    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │ ││    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │ │
#   │    │ 00 *  0.611814    │ ││    │ 00 *  0.995504     │ │
#   │    │ 10    0.161616    │ ││    │ 10    0.00449429   │ │
#   │    │ 01    0.218177    │ ││    │ 01    1.54821e-06  │ │
#   │    │ 11    0.00839352  │ ││    │ 11    6.98951e-09  │ │
#   │    └───────────────────┘ ││    └────────────────────┘ │
#   │  Partitioned repertoire: ││  Partitioned repertoire:  │
#   │    ┌──────────────────┐  ││    ┌────────────────────┐ │
#   │    │ S     Pr(S)      │  ││    │ S     Pr(S)        │ │
#   │    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │  ││    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │ │
#   │    │ 00 *  0.663425   │  ││    │ 00 *  0.948729     │ │
#   │    │ 10    0.126119   │  ││    │ 10    0.0467769    │ │
#   │    │ 01    0.176839   │  ││    │ 01    0.00428312   │ │
#   │    │ 11    0.0336175  │  ││    │ 11    0.000211179  │ │
#   │    └──────────────────┘  ││    └────────────────────┘ │
#   └──────────────────────────┘└───────────────────────────┘
#
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Concept: mechanism = [A,B,C], state = [0, 0, 0], φ = 0.0160392
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#                MIC                           MIE
#   ┌────────────────────────────┐┌────────────────────────────┐
#   │  φ = 0.077012              ││  φ = 0.0160392             │
#   │  Purview: [A,B,C]          ││  Purview: [A,B,C]          │
#   │  MIP:                      ││  MIP:                      │
#   │     ∅    A,B    C          ││     ∅     A    B,C         │
#   │    ─── ✕ ─── ✕ ───         ││    ─── ✕ ─── ✕ ───         │
#   │     ∅    A,B    C          ││     ∅     A    B,C         │
#   │  Repertoire:               ││  Repertoire:               │
#   │    ┌─────────────────────┐ ││    ┌─────────────────────┐ │
#   │    │  S     Pr(S)        │ ││    │  S     Pr(S)        │ │
#   │    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │ ││    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │ │
#   │    │ 000 *  0.457465     │ ││    │ 000 *  0.997633     │ │
#   │    │ 100    0.195359     │ ││    │ 100    0            │ │
#   │    │ 010    0.165774     │ ││    │ 010    1.55152e-06  │ │
#   │    │ 110    0.00904026   │ ││    │ 110    0            │ │
#   │    │ 001    0.134096     │ ││    │ 001    0.00236503   │ │
#   │    │ 101    0.0311206    │ ││    │ 101    0            │ │
#   │    │ 011    0.00688567   │ ││    │ 011    3.67809e-09  │ │
#   │    │ 111    0.000260089  │ ││    │ 111    0            │ │
#   │    └─────────────────────┘ ││    └─────────────────────┘ │
#   │  Partitioned repertoire:   ││  Partitioned repertoire:   │
#   │    ┌────────────────────┐  ││    ┌─────────────────────┐ │
#   │    │  S     Pr(S)       │  ││    │  S     Pr(S)        │ │
#   │    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │  ││    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │ │
#   │    │ 000 *  0.514085    │  ││    │ 000 *  0.986578     │ │
#   │    │ 100    0.183326    │  ││    │ 100    0.00445399   │ │
#   │    │ 010    0.1358      │  ││    │ 010    0.00445399   │ │
#   │    │ 110    0.00705277  │  ││    │ 110    2.01079e-05  │ │
#   │    │ 001    0.0977289   │  ││    │ 001    0.00445399   │ │
#   │    │ 101    0.0348507   │  ││    │ 101    2.01079e-05  │ │
#   │    │ 011    0.0258159   │  ││    │ 011    2.01079e-05  │ │
#   │    │ 111    0.00134075  │  ││    │ 111    9.07791e-08  │ │
#   │    └────────────────────┘  ││    └─────────────────────┘ │
#   └────────────────────────────┘└────────────────────────────┘
#
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Concept: mechanism = [A,B,D], state = [0, 0, 0], φ = 0.0405171
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#               MIC                          MIE
#   ┌──────────────────────────┐┌────────────────────────────┐
#   │  φ = 0.0405171           ││  φ = 0.0706539             │
#   │  Purview: [B,C]          ││  Purview: [A,B,C]          │
#   │  MIP:                    ││  MIP:                      │
#   │     ∅     A    B,D       ││     ∅     A    B,D         │
#   │    ─── ✕ ─── ✕ ───       ││    ─── ✕ ─── ✕ ───         │
#   │     ∅     ∅    B,C       ││     ∅     A    B,C         │
#   │  Repertoire:             ││  Repertoire:               │
#   │    ┌─────────────────┐   ││    ┌─────────────────────┐ │
#   │    │ S     Pr(S)     │   ││    │  S     Pr(S)        │ │
#   │    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │   ││    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │ │
#   │    │ 00 *  0.512301  │   ││    │ 000 *  0.714687     │ │
#   │    │ 10    0.103286  │   ││    │ 100    1.11148e-06  │ │
#   │    │ 01    0.354405  │   ││    │ 010    0.00169427   │ │
#   │    │ 11    0.030009  │   ││    │ 110    2.63492e-09  │ │
#   │    └─────────────────┘   ││    │ 001    0.282946     │ │
#   │  Partitioned repertoire: ││    │ 101    4.40037e-07  │ │
#   │    ┌──────────────────┐  ││    │ 011    0.000670764  │ │
#   │    │ S     Pr(S)      │  ││    │ 111    1.04317e-09  │ │
#   │    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │  ││    └─────────────────────┘ │
#   │    │ 00 *  0.484972   │  ││  Partitioned repertoire:   │
#   │    │ 10    0.121534   │  ││    ┌─────────────────────┐ │
#   │    │ 01    0.356857   │  ││    │  S     Pr(S)        │ │
#   │    │ 11    0.0366361  │  ││    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │ │
#   │    └──────────────────┘  ││    │ 000 *  0.667354     │ │
#   └──────────────────────────┘│    │ 100    0.00301283   │ │
#                               │    │ 010    0.0244673    │ │
#                               │    │ 110    0.00011046   │ │
#                               │    │ 001    0.292944     │ │
#                               │    │ 101    0.00132252   │ │
#                               │    │ 011    0.0107403    │ │
#                               │    │ 111    4.84878e-05  │ │
#                               │    └─────────────────────┘ │
#                               └────────────────────────────┘
#
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Concept: mechanism = [A,C,D], state = [0, 0, 0], φ = 0.0405171
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#               MIC                          MIE
#   ┌──────────────────────────┐┌────────────────────────────┐
#   │  φ = 0.0405171           ││  φ = 0.0706539             │
#   │  Purview: [B,C]          ││  Purview: [B,C,D]          │
#   │  MIP:                    ││  MIP:                      │
#   │     ∅    A,C    D        ││     ∅    A,C    D          │
#   │    ─── ✕ ─── ✕ ───       ││    ─── ✕ ─── ✕ ───         │
#   │     ∅    B,C    ∅        ││     ∅    B,C    D          │
#   │  Repertoire:             ││  Repertoire:               │
#   │    ┌─────────────────┐   ││    ┌─────────────────────┐ │
#   │    │ S     Pr(S)     │   ││    │  S     Pr(S)        │ │
#   │    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │   ││    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │ │
#   │    │ 00 *  0.512301  │   ││    │ 000 *  0.714687     │ │
#   │    │ 10    0.354405  │   ││    │ 100    0.282946     │ │
#   │    │ 01    0.103286  │   ││    │ 010    0.00169427   │ │
#   │    │ 11    0.030009  │   ││    │ 110    0.000670764  │ │
#   │    └─────────────────┘   ││    │ 001    1.11148e-06  │ │
#   │  Partitioned repertoire: ││    │ 101    4.40037e-07  │ │
#   │    ┌──────────────────┐  ││    │ 011    2.63492e-09  │ │
#   │    │ S     Pr(S)      │  ││    │ 111    1.04317e-09  │ │
#   │    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │  ││    └─────────────────────┘ │
#   │    │ 00 *  0.484972   │  ││  Partitioned repertoire:   │
#   │    │ 10    0.356857   │  ││    ┌─────────────────────┐ │
#   │    │ 01    0.121534   │  ││    │  S     Pr(S)        │ │
#   │    │ 11    0.0366361  │  ││    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │ │
#   │    └──────────────────┘  ││    │ 000 *  0.667354     │ │
#   └──────────────────────────┘│    │ 100    0.292944     │ │
#                               │    │ 010    0.0244673    │ │
#                               │    │ 110    0.0107403    │ │
#                               │    │ 001    0.00301283   │ │
#                               │    │ 101    0.00132252   │ │
#                               │    │ 011    0.00011046   │ │
#                               │    │ 111    4.84878e-05  │ │
#                               │    └─────────────────────┘ │
#                               └────────────────────────────┘
#
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Concept: mechanism = [B,C,D], state = [0, 0, 0], φ = 0.0160392
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#                MIC                           MIE
#   ┌────────────────────────────┐┌────────────────────────────┐
#   │  φ = 0.077012              ││  φ = 0.0160392             │
#   │  Purview: [B,C,D]          ││  Purview: [B,C,D]          │
#   │  MIP:                      ││  MIP:                      │
#   │     ∅     B    C,D         ││     ∅    B,C    D          │
#   │    ─── ✕ ─── ✕ ───         ││    ─── ✕ ─── ✕ ───         │
#   │     ∅     B    C,D         ││     ∅    B,C    D          │
#   │  Repertoire:               ││  Repertoire:               │
#   │    ┌─────────────────────┐ ││    ┌─────────────────────┐ │
#   │    │  S     Pr(S)        │ ││    │  S     Pr(S)        │ │
#   │    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │ ││    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │ │
#   │    │ 000 *  0.457465     │ ││    │ 000 *  0.997633     │ │
#   │    │ 100    0.134096     │ ││    │ 100    0.00236503   │ │
#   │    │ 010    0.165774     │ ││    │ 010    1.55152e-06  │ │
#   │    │ 110    0.00688567   │ ││    │ 110    3.67809e-09  │ │
#   │    │ 001    0.195359     │ ││    │ 001    0            │ │
#   │    │ 101    0.0311206    │ ││    │ 101    0            │ │
#   │    │ 011    0.00904026   │ ││    │ 011    0            │ │
#   │    │ 111    0.000260089  │ ││    │ 111    0            │ │
#   │    └─────────────────────┘ ││    └─────────────────────┘ │
#   │  Partitioned repertoire:   ││  Partitioned repertoire:   │
#   │    ┌────────────────────┐  ││    ┌─────────────────────┐ │
#   │    │  S     Pr(S)       │  ││    │  S     Pr(S)        │ │
#   │    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │  ││    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │ │
#   │    │ 000 *  0.514085    │  ││    │ 000 *  0.986578     │ │
#   │    │ 100    0.0977289   │  ││    │ 100    0.00445399   │ │
#   │    │ 010    0.1358      │  ││    │ 010    0.00445399   │ │
#   │    │ 110    0.0258159   │  ││    │ 110    2.01079e-05  │ │
#   │    │ 001    0.183326    │  ││    │ 001    0.00445399   │ │
#   │    │ 101    0.0348507   │  ││    │ 101    2.01079e-05  │ │
#   │    │ 011    0.00705277  │  ││    │ 011    2.01079e-05  │ │
#   │    │ 111    0.00134075  │  ││    │ 111    9.07791e-08  │ │
#   │    └────────────────────┘  ││    └─────────────────────┘ │
#   └────────────────────────────┘└────────────────────────────┘
#
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Concept: mechanism = [A,B,C,D], state = [0, 0, 0, 0], φ = 0.00991683
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#                 MIC                            MIE
#   ┌─────────────────────────────┐┌─────────────────────────────┐
#   │  φ = 0.0368791              ││  φ = 0.00991683             │
#   │  Purview: [A,B,C,D]         ││  Purview: [A,B,C,D]         │
#   │  MIP:                       ││  MIP:                       │
#   │     ∅    A,C,D    B         ││     ∅     A    B,C,D        │
#   │    ─── ✕ ───── ✕ ───        ││    ─── ✕ ─── ✕ ─────        │
#   │     ∅     A,D    B,C        ││     ∅     A    B,C,D        │
#   │  Repertoire:                ││  Repertoire:                │
#   │    ┌──────────────────────┐ ││    ┌────────────────┐       │
#   │    │  S      Pr(S)        │ ││    │  S      Pr(S)  │       │
#   │    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │ ││    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │       │
#   │    │ 0000 *  0.313008     │ ││    │ 0000 *  1      │       │
#   │    │ 1000    0.134818     │ ││    │ 1000    0      │       │
#   │    │ 0100    0.13418      │ ││    │ 0100    0      │       │
#   │    │ 1100    0.00765278   │ ││    │ 1100    0      │       │
#   │    │ 0010    0.13418      │ ││    │ 0010    0      │       │
#   │    │ 1010    0.0325621    │ ││    │ 1010    0      │       │
#   │    │ 0110    0.00755145   │ ││    │ 0110    0      │       │
#   │    │ 1110    0.000279918  │ ││    │ 1110    0      │       │
#   │    │ 0001    0.134818     │ ││    │ 0001    0      │       │
#   │    │ 1001    0.0570795    │ ││    │ 1001    0      │       │
#   │    │ 0101    0.0325621    │ ││    │ 0101    0      │       │
#   │    │ 1101    0.00168238   │ ││    │ 1101    0      │       │
#   │    │ 0011    0.00765278   │ ││    │ 0011    0      │       │
#   │    │ 1011    0.00168238   │ ││    │ 1011    0      │       │
#   │    │ 0111    0.000279918  │ ││    │ 0111    0      │       │
#   │    │ 1111    1.09341e-05  │ ││    │ 1111    0      │       │
#   │    └──────────────────────┘ ││    └────────────────┘       │
#   │  Partitioned repertoire:    ││  Partitioned repertoire:    │
#   │    ┌─────────────────────┐  ││    ┌──────────────────────┐ │
#   │    │  S      Pr(S)       │  ││    │  S      Pr(S)        │ │
#   │    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │  ││    │ ╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴╴ │ │
#   │    │ 0000 *  0.288461    │  ││    │ 0000 *  0.99315      │ │
#   │    │ 1000    0.0731004   │  ││    │ 1000    0.00448366   │ │
#   │    │ 0100    0.0768904   │  ││    │ 0100    0.0023544    │ │
#   │    │ 1100    0.0194852   │  ││    │ 1100    1.06292e-05  │ │
#   │    │ 0010    0.263835    │  ││    │ 0010    1.54454e-06  │ │
#   │    │ 1010    0.0668597   │  ││    │ 1010    6.97298e-09  │ │
#   │    │ 0110    0.0281025   │  ││    │ 0110    3.66156e-09  │ │
#   │    │ 1110    0.00712159  │  ││    │ 1110    1.65304e-11  │ │
#   │    │ 0001    0.0618406   │  ││    │ 0001    0            │ │
#   │    │ 1001    0.015463    │  ││    │ 1001    0            │ │
#   │    │ 0101    0.0164839   │  ││    │ 0101    0            │ │
#   │    │ 1101    0.00412173  │  ││    │ 1101    0            │ │
#   │    │ 0011    0.0565612   │  ││    │ 0011    0            │ │
#   │    │ 1011    0.0141429   │  ││    │ 1011    0            │ │
#   │    │ 0111    0.00602464  │  ││    │ 0111    0            │ │
#   │    │ 1111    0.00150644  │  ││    │ 1111    0            │ │
#   │    └─────────────────────┘  ││    └──────────────────────┘ │
#   └─────────────────────────────┘└─────────────────────────────┘

# %%
#Compute all relations
relations = list(pyphi.relations.relations(subsystem,sep(distinctions),max_degree=2))
# Out:
#   0%|          | 0/334 [00:00<?, ?it/s]
# /home/diego/anaconda3/lib/python3.9/site-packages/pyphi/pyphi/utils.py:87: RuntimeWarning: invalid value encountered in double_scalars
#   return abs(x - y) <= constants.EPSILON

# %%
relations
# Out:
# [Relation(relata=(Effect[0,2,3],Cause[2]), purview=frozenset({2}), phi=0.5824214947027485),
#  Relation(relata=(Cause[0,1],Cause[1]), purview=frozenset({1}), phi=0.3485718560370109),
#  Relation(relata=(Cause[0,2],Effect[0,3]), purview=frozenset({1}), phi=0.07886056238260826),
#  Relation(relata=(Cause[1,3],Cause[1,2,3]), purview=frozenset({2}), phi=0.16776015858407486),
#  Relation(relata=(Effect[0,1],Cause[0,1,3]), purview=frozenset({1}), phi=0.3738936916172339),
#  Relation(relata=(Cause[1,3],Effect[1,3]), purview=frozenset({2}), phi=0.16776015858407486),
#  Relation(relata=(Effect[0,2,3],Effect[3]), purview=frozenset({3}), phi=0.4756872078760291),
#  Relation(relata=(Effect[0,1],Effect[0,3]), purview=frozenset({1}), phi=0.07886056238260826),
#  Relation(relata=(Cause[0],Effect[0,1,2,3]), purview=frozenset({0}), phi=0.5203817439621854),
#  Relation(relata=(Cause[0,2,3],Effect[2]), purview=frozenset({2}), phi=0.37389369161723407),
#  Relation(relata=(Effect[0,2],Cause[1,2]), purview=frozenset({1, 2}), phi=0.6115467676450679),
#  Relation(relata=(Cause[0,2],Cause[0,1,2]), purview=frozenset({1}), phi=0.16776015858407486),
#  Relation(relata=(Effect[1,2,3],Effect[1]), purview=frozenset({1}), phi=0.7137239705010131),
#  Relation(relata=(Cause[0,1],Effect[1]), purview=frozenset({1}), phi=0.3485718560370109),
#  Relation(relata=(Effect[0,1,2],Cause[0,1,3]), purview=frozenset({1, 2}), phi=0.5302633237693963),
#  Relation(relata=(Cause[0,2],Cause[0,3]), purview=frozenset({1}), phi=0.06050021910372112),
#  Relation(relata=(Cause[2,3],Effect[2]), purview=frozenset({2}), phi=0.3485718560370109),
#  Relation(relata=(Cause[2,3],Cause[1,2,3]), purview=frozenset({2, 3}), phi=0.4823422631982804),
#  Relation(relata=(Effect[0,3],Cause[0,1,3]), purview=frozenset({1, 2}), phi=0.1577211247652166),
#  Relation(relata=(Effect[1],Cause[0,1,2,3]), purview=frozenset({1}), phi=0.08278086747512967),
#  Relation(relata=(Effect[2,3],Effect[2]), purview=frozenset({2}), phi=0.7137239705010137),
#  Relation(relata=(Effect[0,2,3],Cause[0,1,2,3]), purview=frozenset({1, 2}), phi=0.26126230321719374),
#  Relation(relata=(Effect[0,2,3],Cause[0,1,3]), purview=frozenset({1, 2}), phi=0.3603999533918335),
#  Relation(relata=(Cause[2],Effect[2]), purview=frozenset({2}), phi=0.629285242579019),
#  Relation(relata=(Cause[0,1,2],Cause[0,1,2,3]), purview=frozenset({0, 1, 2}), phi=0.3621610479246914),
#  Relation(relata=(Cause[1,2,3],Effect[0,1,3]), purview=frozenset({1, 2}), phi=0.47654005507952046),
#  Relation(relata=(Effect[1],Cause[0,3]), purview=frozenset({1}), phi=0.06050021910372112),
#  Relation(relata=(Cause[0,2,3],Effect[0,2,3]), purview=frozenset({1, 2}), phi=0.5302633237693966),
#  Relation(relata=(Cause[0,1,2,3],Effect[0,1,2]), purview=frozenset({0, 1, 2}), phi=0.3621610479246914),
#  Relation(relata=(Cause[0,1,2,3],Effect[0,3]), purview=frozenset({1, 2}), phi=0.1577211247652166),
#  Relation(relata=(Cause[0,3],Cause[0,1,3]), purview=frozenset({1, 2}), phi=0.116003352756677),
#  Relation(relata=(Cause[1],Cause[1,2]), purview=frozenset({1}), phi=0.4153811206299698),
#  Relation(relata=(Effect[1,3],Cause[0,1,3]), purview=frozenset({1, 2}), phi=0.5302633237693963),
#  Relation(relata=(Cause[0,1],Effect[0,3]), purview=frozenset({1}), phi=0.07886056238260826),
#  Relation(relata=(Effect[0,2,3],Effect[0,1,2]), purview=frozenset({1, 2}), phi=0.823378657988878),
#  Relation(relata=(Effect[0,1],Cause[0,1,2,3]), purview=frozenset({0, 1}), phi=0.1756225857962925),
#  Relation(relata=(Effect[0,2,3],Effect[1,2]), purview=frozenset({1, 2}), phi=0.823378657988878),
#  Relation(relata=(Effect[0],Cause[0,1,2,3]), purview=frozenset({0}), phi=0.05384847129222373),
#  Relation(relata=(Effect[0,1],Effect[1]), purview=frozenset({1}), phi=0.7137239705010131),
#  Relation(relata=(Cause[0,2,3],Cause[1,2]), purview=frozenset({1, 2}), phi=0.5302633237693966),
#  Relation(relata=(Cause[1,2],Effect[0,1,3]), purview=frozenset({1, 2}), phi=0.6563382839160995),
#  Relation(relata=(Cause[0,1,2,3],Cause[0,1,3]), purview=frozenset({1, 2}), phi=0.2022236575808337),
#  Relation(relata=(Effect[2,3],Cause[0,1,2,3]), purview=frozenset({2}), phi=0.15433012402409746),
#  Relation(relata=(Effect[0,2,3],Effect[0,1,3]), purview=frozenset({1, 2}), phi=0.4819143265722592),
#  Relation(relata=(Cause[0,2,3],Cause[0,1,2]), purview=frozenset({1, 2}), phi=0.3550256818990947),
#  Relation(relata=(Effect[1,2,3],Cause[0,1,3]), purview=frozenset({1, 2}), phi=0.5302633237693963),
#  Relation(relata=(Effect[0,2],Cause[2]), purview=frozenset({2}), phi=0.5125545880051706),
#  Relation(relata=(Cause[1,2],Cause[0,1,3]), purview=frozenset({1, 2}), phi=0.5302633237693963),
#  Relation(relata=(Cause[0,2],Effect[0,1,2,3]), purview=frozenset({1}), phi=0.16776015858407486),
#  Relation(relata=(Cause[0,2,3],Effect[0,1,2,3]), purview=frozenset({1, 2}), phi=0.5302633237693966),
#  Relation(relata=(Effect[2,3],Cause[0,1,2]), purview=frozenset({2}), phi=0.23558289179339065),
#  Relation(relata=(Cause[0,1,2],Effect[0,1,2,3]), purview=frozenset({0, 1, 2}), phi=0.8562529985412689),
#  Relation(relata=(Cause[0,1],Effect[0,2]), purview=frozenset({0, 1}), phi=0.5013485655544765),
#  Relation(relata=(Effect[0,1],Cause[0,2]), purview=frozenset({1}), phi=0.16776015858407486),
#  Relation(relata=(Cause[2,3],Effect[0,2]), purview=frozenset({2}), phi=0.3485718560370109),
#  Relation(relata=(Effect[0,2,3],Effect[1,2,3]), purview=frozenset({1, 2, 3}), phi=1.299065865864907),
#  Relation(relata=(Effect[1,2,3],Cause[0,1,2]), purview=frozenset({1, 2}), phi=0.5198279482519588),
#  Relation(relata=(Cause[0,1],Effect[1,2,3]), purview=frozenset({1}), phi=0.3485718560370109),
#  Relation(relata=(Effect[0,1],Cause[0,1,2]), purview=frozenset({0, 1}), phi=0.48781559312218187),
#  Relation(relata=(Cause[0],Effect[0,2]), purview=frozenset({0}), phi=0.44284970279625413),
#  Relation(relata=(Cause[0,2,3],Cause[2]), purview=frozenset({2}), phi=0.37389369161723407),
#  Relation(relata=(Effect[1],Effect[0,1,2,3]), purview=frozenset({1}), phi=0.7137239705010131),
#  Relation(relata=(Cause[0,1],Effect[0,1,2]), purview=frozenset({0, 1}), phi=0.7899526207821111),
#  Relation(relata=(Cause[2,3],Effect[3]), purview=frozenset({3}), phi=0.3051829185393784),
#  Relation(relata=(Effect[1,3],Cause[2]), purview=frozenset({2}), phi=0.19616564701509828),
#  Relation(relata=(Effect[1,2,3],Cause[2]), purview=frozenset({2}), phi=0.629285242579019),
#  Relation(relata=(Effect[0,2,3],Cause[0,2]), purview=frozenset({1}), phi=0.16776015858407486),
#  Relation(relata=(Effect[2,3],Cause[3]), purview=frozenset({3}), phi=0.5203817439621854),
#  Relation(relata=(Effect[0,2,3],Cause[0,3]), purview=frozenset({1, 2}), phi=0.116003352756677),
#  Relation(relata=(Cause[0,3],Cause[0,1,2]), purview=frozenset({1, 2}), phi=0.116003352756677),
#  Relation(relata=(Cause[0],Cause[0,1]), purview=frozenset({0}), phi=0.3051829185393784),
#  Relation(relata=(Effect[1],Effect[1,2]), purview=frozenset({1}), phi=0.7137239705010131),
#  Relation(relata=(Cause[0,1],Effect[1,3]), purview=frozenset({1}), phi=0.3485718560370109),
#  Relation(relata=(Cause[0,3],Cause[1,2]), purview=frozenset({1, 2}), phi=0.116003352756677),
#  Relation(relata=(Cause[0,1,2,3],Effect[0,1,2,3]), purview=frozenset({0, 1, 2}), phi=0.3621610479246914),
#  Relation(relata=(Cause[0,2],Effect[1]), purview=frozenset({1}), phi=0.16776015858407486),
#  Relation(relata=(Effect[2,3],Effect[0,3]), purview=frozenset({2}), phi=0.07886056238260837),
#  Relation(relata=(Effect[1,2,3],Effect[0,1,2,3]), purview=frozenset({1, 2, 3}), phi=2.2934270330882263),
#  Relation(relata=(Cause[0,3],Cause[0,1,2,3]), purview=frozenset({1, 2}), phi=0.116003352756677),
#  Relation(relata=(Effect[0,1,2,3],Cause[1,2]), purview=frozenset({1, 2}), phi=0.9470674774522065),
#  Relation(relata=(Effect[1],Effect[0,1,2]), purview=frozenset({1}), phi=0.7137239705010131),
#  Relation(relata=(Cause[1],Effect[1]), purview=frozenset({1}), phi=0.629285242579019),
#  Relation(relata=(Cause[2,3],Cause[0,1,2,3]), purview=frozenset({2}), phi=0.15433012402409746),
#  Relation(relata=(Cause[0,2],Cause[0,1,3]), purview=frozenset({1}), phi=0.16776015858407486),
#  Relation(relata=(Effect[2,3],Cause[1,2]), purview=frozenset({2}), phi=0.4153811206299698),
#  Relation(relata=(Cause[0,2,3],Cause[0,1,3]), purview=frozenset({1, 2}), phi=0.2388855802114081),
#  Relation(relata=(Cause[0,1,3],Effect[0,1,3]), purview=frozenset({1, 2}), phi=0.5302633237693963),
#  Relation(relata=(Cause[1,3],Cause[0,3]), purview=frozenset({2}), phi=0.06050021910372112),
#  Relation(relata=(Cause[1,3],Effect[1,2]), purview=frozenset({2}), phi=0.16776015858407486),
#  Relation(relata=(Effect[0,1],Cause[1,2]), purview=frozenset({1}), phi=0.4153811206299698),
#  Relation(relata=(Effect[0,2],Effect[1]), purview=frozenset({1}), phi=0.1961656470150981),
#  Relation(relata=(Effect[1],Effect[0,1,3]), purview=frozenset({1}), phi=0.5824214947027483),
#  Relation(relata=(Cause[0,2,3],Cause[1,2,3]), purview=frozenset({1, 2}), phi=0.29660213476460606),
#  Relation(relata=(Effect[1,2,3],Cause[1,2]), purview=frozenset({1, 2}), phi=0.9470674774522065),
#  Relation(relata=(Effect[2,3],Effect[0,1,2,3]), purview=frozenset({2, 3}), phi=1.4707948357090543),
#  Relation(relata=(Effect[0,2],Effect[0,1,3]), purview=frozenset({0, 1, 2}), phi=0.8799725130974819),
#  Relation(relata=(Cause[1,2,3],Effect[1,2]), purview=frozenset({1, 2}), phi=0.5198279482519591),
#  Relation(relata=(Cause[0],Effect[0,1]), purview=frozenset({0}), phi=0.5203817439621854),
#  Relation(relata=(Cause[0,2],Cause[1,2,3]), purview=frozenset({1}), phi=0.16776015858407486),
#  Relation(relata=(Cause[0,2],Effect[0,1,2]), purview=frozenset({1}), phi=0.16776015858407486),
#  Relation(relata=(Effect[1],Cause[0,1,3]), purview=frozenset({1}), phi=0.3738936916172339),
#  Relation(relata=(Effect[0],Effect[0,2]), purview=frozenset({0}), phi=0.44284970279625413),
#  Relation(relata=(Effect[1,3],Effect[2,3]), purview=frozenset({2, 3}), phi=0.6390153498113522),
#  Relation(relata=(Cause[1,3],Effect[0,1,3]), purview=frozenset({2}), phi=0.16776015858407486),
#  Relation(relata=(Effect[1,3],Effect[3]), purview=frozenset({3}), phi=0.44284970279625413),
#  Relation(relata=(Cause[1,2,3],Effect[0,1,2]), purview=frozenset({1, 2}), phi=0.5198279482519591),
#  Relation(relata=(Effect[0,1],Effect[0,1,2,3]), purview=frozenset({0, 1}), phi=1.4707948357090541),
#  Relation(relata=(Effect[0,1,2,3],Cause[3]), purview=frozenset({3}), phi=0.5203817439621854),
#  Relation(relata=(Effect[0,1],Effect[1,3]), purview=frozenset({1}), phi=0.5125545880051705),
#  Relation(relata=(Effect[0,2],Effect[2]), purview=frozenset({2}), phi=0.5125545880051706),
#  Relation(relata=(Cause[0,2],Effect[0,1,3]), purview=frozenset({1}), phi=0.16776015858407486),
#  Relation(relata=(Cause[2],Effect[0,3]), purview=frozenset({2}), phi=0.07886056238260837),
#  Relation(relata=(Effect[0,1],Cause[1,2,3]), purview=frozenset({1}), phi=0.2355828917933908),
#  Relation(relata=(Cause[1,3],Cause[0,1,3]), purview=frozenset({2}), phi=0.11944279010570402),
#  Relation(relata=(Cause[0,3],Effect[0,1,3]), purview=frozenset({1, 2}), phi=0.116003352756677),
#  Relation(relata=(Cause[0,1],Cause[0,3]), purview=frozenset({1}), phi=0.06050021910372112),
#  Relation(relata=(Effect[1,3],Cause[1,2]), purview=frozenset({1, 2}), phi=0.6115467676450681),
#  Relation(relata=(Effect[2],Cause[0,1,3]), purview=frozenset({2}), phi=0.11944279010570402),
#  Relation(relata=(Effect[1,3],Effect[0,3]), purview=frozenset({1, 2}), phi=0.1577211247652166),
#  Relation(relata=(Cause[2],Cause[0,1,2]), purview=frozenset({2}), phi=0.23558289179339065),
#  Relation(relata=(Cause[2,3],Effect[0,3]), purview=frozenset({2}), phi=0.07886056238260837),
#  Relation(relata=(Cause[1,2,3],Cause[0,1,3]), purview=frozenset({1, 2}), phi=0.3550256818990948),
#  Relation(relata=(Effect[0,3],Effect[0,1,3]), purview=frozenset({1, 2}), phi=0.1577211247652166),
#  Relation(relata=(Effect[0,2,3],Cause[1]), purview=frozenset({1}), phi=0.2409571632861295),
#  Relation(relata=(Cause[0,1,2],Effect[0,3]), purview=frozenset({1, 2}), phi=0.1577211247652166),
#  Relation(relata=(Cause[2],Effect[1,2]), purview=frozenset({2}), phi=0.629285242579019),
#  Relation(relata=(Cause[2],Cause[0,3]), purview=frozenset({2}), phi=0.06050021910372112),
#  Relation(relata=(Cause[0,2,3],Effect[0,3]), purview=frozenset({1, 2}), phi=0.1577211247652166),
#  Relation(relata=(Cause[0,2,3],Effect[1,2,3]), purview=frozenset({1, 2}), phi=0.5302633237693966),
#  Relation(relata=(Cause[0,1],Cause[0,1,2]), purview=frozenset({0, 1}), phi=0.4823422631982802),
#  Relation(relata=(Effect[1,2,3],Effect[0,1,3]), purview=frozenset({1, 2}), phi=0.823378657988878),
#  Relation(relata=(Effect[1,3],Effect[1]), purview=frozenset({1}), phi=0.5125545880051705),
#  Relation(relata=(Effect[0,1,2],Effect[0,3]), purview=frozenset({1, 2}), phi=0.1577211247652166),
#  Relation(relata=(Cause[0,1],Cause[1,2,3]), purview=frozenset({1}), phi=0.2355828917933908),
#  Relation(relata=(Cause[0,3],Effect[0,1,2,3]), purview=frozenset({1, 2}), phi=0.116003352756677),
#  Relation(relata=(Cause[0,1,2,3],Cause[1,2]), purview=frozenset({1, 2}), phi=0.26126230321719374),
#  Relation(relata=(Effect[1,2,3],Cause[0,1,2,3]), purview=frozenset({1, 2}), phi=0.26126230321719374),
#  Relation(relata=(Effect[0,3],Effect[1,2]), purview=frozenset({1, 2}), phi=0.1577211247652166),
#  Relation(relata=(Cause[1,3],Cause[2,3]), purview=frozenset({2}), phi=0.16776015858407486),
#  Relation(relata=(Cause[0],Cause[0,1,2,3]), purview=frozenset({0}), phi=0.05384847129222373),
#  Relation(relata=(Cause[1,3],Effect[1,2,3]), purview=frozenset({2}), phi=0.16776015858407486),
#  Relation(relata=(Effect[0,2,3],Cause[1,2]), purview=frozenset({1, 2}), phi=0.6563382839160993),
#  Relation(relata=(Cause[1,3],Effect[0,1,2,3]), purview=frozenset({2}), phi=0.16776015858407486),
#  Relation(relata=(Cause[1,3],Cause[0,1,2,3]), purview=frozenset({2}), phi=0.15433012402409746),
#  Relation(relata=(Effect[1,3],Cause[0,2]), purview=frozenset({1}), phi=0.16776015858407486),
#  Relation(relata=(Cause[1],Effect[0,1,2,3]), purview=frozenset({1}), phi=0.629285242579019),
#  Relation(relata=(Cause[1,3],Cause[2]), purview=frozenset({2}), phi=0.16776015858407486),
#  Relation(relata=(Effect[1,3],Cause[1,2,3]), purview=frozenset({1, 2, 3}), phi=0.671925071569441),
#  Relation(relata=(Effect[1,3],Effect[0,1,2]), purview=frozenset({1, 2}), phi=0.7087202350202687),
#  Relation(relata=(Effect[0,2],Cause[0,1,2,3]), purview=frozenset({0, 1, 2}), phi=0.3621610479246914),
#  Relation(relata=(Effect[1,3],Effect[0,2]), purview=frozenset({1, 2}), phi=0.3923312940301964),
#  Relation(relata=(Cause[0,2,3],Effect[1]), purview=frozenset({1}), phi=0.11944279010570406),
#  Relation(relata=(Effect[1],Cause[0,1,2]), purview=frozenset({1}), phi=0.17715934465890185),
#  Relation(relata=(Effect[0,2,3],Cause[1,2,3]), purview=frozenset({1, 2, 3}), phi=0.7287727564083114),
#  Relation(relata=(Effect[1,2,3],Effect[2]), purview=frozenset({2}), phi=0.7137239705010137),
#  Relation(relata=(Effect[2],Cause[1,2]), purview=frozenset({2}), phi=0.4153811206299698),
#  Relation(relata=(Effect[0,1,2,3],Cause[0,1,3]), purview=frozenset({1, 2}), phi=0.5302633237693963),
#  Relation(relata=(Cause[1,3],Cause[0,1,2]), purview=frozenset({2}), phi=0.16776015858407486),
#  Relation(relata=(Cause[0,2],Cause[0,1,2,3]), purview=frozenset({1}), phi=0.08278086747512967),
#  Relation(relata=(Cause[1,2,3],Effect[0,3]), purview=frozenset({1, 2}), phi=0.1577211247652166),
#  Relation(relata=(Cause[2,3],Cause[0,1,3]), purview=frozenset({2}), phi=0.11944279010570402),
#  Relation(relata=(Effect[0,3],Effect[2]), purview=frozenset({2}), phi=0.07886056238260837),
#  Relation(relata=(Effect[0,1],Cause[1]), purview=frozenset({1}), phi=0.629285242579019),
#  Relation(relata=(Effect[1,3],Cause[3]), purview=frozenset({3}), phi=0.44284970279625413),
#  Relation(relata=(Cause[1,2,3],Cause[3]), purview=frozenset({3}), phi=0.1786285822145354),
#  Relation(relata=(Cause[1,3],Effect[0,3]), purview=frozenset({2}), phi=0.07886056238260837),
#  Relation(relata=(Cause[0,2,3],Cause[0,2]), purview=frozenset({1}), phi=0.11944279010570406),
#  Relation(relata=(Cause[0,2,3],Cause[0,3]), purview=frozenset({1, 2}), phi=0.116003352756677),
#  Relation(relata=(Cause[0,3],Effect[2]), purview=frozenset({2}), phi=0.06050021910372112),
#  Relation(relata=(Cause[0,2,3],Effect[0,1]), purview=frozenset({1}), phi=0.11944279010570406),
#  Relation(relata=(Effect[2,3],Effect[0,1,2]), purview=frozenset({2}), phi=0.8081994167393834),
#  Relation(relata=(Effect[1],Cause[1,2]), purview=frozenset({1}), phi=0.4153811206299698),
#  Relation(relata=(Effect[0,1,2,3],Effect[1,2]), purview=frozenset({1, 2}), phi=1.6091367565269208),
#  Relation(relata=(Cause[2,3],Effect[0,1,2]), purview=frozenset({2}), phi=0.3485718560370109),
#  Relation(relata=(Effect[2,3],Effect[1,2]), purview=frozenset({2}), phi=0.8045683782634602),
#  Relation(relata=(Cause[1],Cause[0,3]), purview=frozenset({1}), phi=0.06050021910372112),
#  Relation(relata=(Cause[2],Effect[0,1,3]), purview=frozenset({2}), phi=0.2409571632861297),
#  Relation(relata=(Cause[0,3],Effect[0,3]), purview=frozenset({1, 2}), phi=0.116003352756677),
#  Relation(relata=(Cause[1,2,3],Effect[2,3]), purview=frozenset({2, 3}), phi=0.4878155931221819),
#  Relation(relata=(Cause[0,2,3],Cause[1]), purview=frozenset({1}), phi=0.11944279010570406),
#  Relation(relata=(Effect[2,3],Effect[0,2]), purview=frozenset({2}), phi=0.5125545880051706),
#  Relation(relata=(Effect[0,2],Effect[0,1,2,3]), purview=frozenset({0, 1, 2}), phi=1.151569937816523),
#  Relation(relata=(Effect[2,3],Effect[0,1,3]), purview=frozenset({2}), phi=0.2409571632861297),
#  Relation(relata=(Cause[1],Effect[0,1,3]), purview=frozenset({1}), phi=0.5824214947027483),
#  Relation(relata=(Effect[0,2,3],Effect[0,3]), purview=frozenset({1, 2}), phi=0.1577211247652166),
#  Relation(relata=(Cause[0],Effect[0,1,2]), purview=frozenset({0}), phi=0.5203817439621854),
#  Relation(relata=(Cause[1,3],Effect[2]), purview=frozenset({2}), phi=0.16776015858407486),
#  Relation(relata=(Effect[0,2,3],Cause[2,3]), purview=frozenset({2, 3}), phi=0.7899526207821111),
#  Relation(relata=(Effect[1,2,3],Effect[0,2]), purview=frozenset({1, 2}), phi=0.7087202350202687),
#  Relation(relata=(Cause[2,3],Effect[0,1,3]), purview=frozenset({2}), phi=0.2409571632861297),
#  Relation(relata=(Cause[0,1],Cause[0,2]), purview=frozenset({1}), phi=0.16776015858407486),
#  Relation(relata=(Effect[0,1],Effect[0,2]), purview=frozenset({0, 1}), phi=0.6390153498113522),
#  Relation(relata=(Effect[1,2,3],Effect[1,2]), purview=frozenset({1, 2}), phi=1.6091367565269208),
#  Relation(relata=(Cause[0,1],Effect[1,2]), purview=frozenset({1}), phi=0.3485718560370109),
#  Relation(relata=(Cause[1],Cause[0,1,2,3]), purview=frozenset({1}), phi=0.08278086747512967),
#  Relation(relata=(Cause[0],Cause[0,1,2]), purview=frozenset({0}), phi=0.17862858221453526),
#  Relation(relata=(Effect[2,3],Effect[3]), purview=frozenset({3}), phi=0.6561293724897728),
#  Relation(relata=(Effect[0,1,2,3],Effect[3]), purview=frozenset({3}), phi=0.6561293724897728),
#  Relation(relata=(Cause[1],Effect[1,2,3]), purview=frozenset({1}), phi=0.629285242579019),
#  Relation(relata=(Effect[1,2,3],Effect[0,1,2]), purview=frozenset({1, 2}), phi=1.626006423061491),
#  Relation(relata=(Cause[1],Cause[1,2,3]), purview=frozenset({1}), phi=0.2355828917933908),
#  Relation(relata=(Cause[1,2,3],Cause[2]), purview=frozenset({2}), phi=0.17715934465890198),
#  Relation(relata=(Effect[0,2],Cause[0,3]), purview=frozenset({1, 2}), phi=0.116003352756677),
#  Relation(relata=(Cause[0,1,2],Cause[1,2]), purview=frozenset({1, 2}), phi=0.5198279482519588),
#  Relation(relata=(Effect[0,2,3],Effect[0,2]), purview=frozenset({1, 2}), phi=0.7087202350202687),
#  Relation(relata=(Cause[2,3],Effect[1,2,3]), purview=frozenset({2, 3}), phi=0.7899526207821111),
#  Relation(relata=(Cause[2,3],Cause[1,2]), purview=frozenset({2}), phi=0.3485718560370109),
#  Relation(relata=(Effect[1,3],Cause[1]), purview=frozenset({1}), phi=0.5125545880051705),
#  Relation(relata=(Cause[0,1,3],Effect[1,2]), purview=frozenset({1, 2}), phi=0.5302633237693963),
#  Relation(relata=(Effect[0,1,2,3],Effect[2]), purview=frozenset({2}), phi=0.7137239705010137),
#  Relation(relata=(Cause[1,3],Cause[0,2,3]), purview=frozenset({2}), phi=0.16776015858407486),
#  Relation(relata=(Cause[1,2,3],Effect[0,1,2,3]), purview=frozenset({1, 2, 3}), phi=0.8562529985412691),
#  Relation(relata=(Effect[0,2],Cause[0,1,3]), purview=frozenset({1, 2}), phi=0.3156084371208021),
#  Relation(relata=(Cause[2],Cause[1,2]), purview=frozenset({2}), phi=0.4153811206299698),
#  Relation(relata=(Effect[0],Effect[0,1,2]), purview=frozenset({0}), phi=0.6561293724897728),
#  Relation(relata=(Cause[0,2,3],Effect[1,3]), purview=frozenset({1, 2}), phi=0.31560843712080233),
#  Relation(relata=(Effect[0,2,3],Effect[1]), purview=frozenset({1}), phi=0.2409571632861295),
#  Relation(relata=(Cause[1,2,3],Cause[0,1,2]), purview=frozenset({1, 2}), phi=0.35431868931780386),
#  Relation(relata=(Effect[1,3],Effect[0,1,3]), purview=frozenset({1, 2}), phi=0.7087202350202687),
#  Relation(relata=(Effect[1,3],Cause[0,1,2]), purview=frozenset({1, 2}), phi=0.37332499167400013),
#  Relation(relata=(Cause[0,1,2],Effect[0,1,3]), purview=frozenset({0, 1, 2}), phi=0.7287727564083115),
#  Relation(relata=(Cause[0,2],Effect[1,2]), purview=frozenset({1}), phi=0.16776015858407486),
#  Relation(relata=(Cause[0,1],Cause[1,2]), purview=frozenset({1}), phi=0.3485718560370109),
#  Relation(relata=(Effect[1,3],Cause[0,3]), purview=frozenset({1, 2}), phi=0.116003352756677),
#  Relation(relata=(Cause[0,1,2,3],Effect[1,2]), purview=frozenset({1, 2}), phi=0.26126230321719374),
#  Relation(relata=(Effect[0],Effect[0,1,3]), purview=frozenset({0}), phi=0.4756872078760291),
#  Relation(relata=(Cause[1,3],Effect[0,2]), purview=frozenset({2}), phi=0.16776015858407486),
#  Relation(relata=(Effect[1,2,3],Effect[0,3]), purview=frozenset({1, 2}), phi=0.1577211247652166),
#  Relation(relata=(Effect[0,2],Effect[0,1,2]), purview=frozenset({0, 1, 2}), phi=1.151569937816523),
#  Relation(relata=(Cause[0,1],Effect[0]), purview=frozenset({0}), phi=0.3051829185393784),
#  Relation(relata=(Cause[2,3],Cause[3]), purview=frozenset({3}), phi=0.3051829185393784),
#  Relation(relata=(Effect[0,2],Effect[1,2]), purview=frozenset({1, 2}), phi=0.7087202350202687),
#  Relation(relata=(Effect[0,1],Effect[1,2,3]), purview=frozenset({1}), phi=0.8081994167393829),
#  Relation(relata=(Effect[0,2,3],Effect[2]), purview=frozenset({2}), phi=0.5824214947027485),
#  Relation(relata=(Effect[0,1],Effect[0,2,3]), purview=frozenset({1}), phi=0.2409571632861295),
#  Relation(relata=(Effect[1,2,3],Cause[0,3]), purview=frozenset({1, 2}), phi=0.116003352756677),
#  Relation(relata=(Cause[0,3],Effect[1,2]), purview=frozenset({1, 2}), phi=0.116003352756677),
#  Relation(relata=(Cause[1],Cause[0,1,3]), purview=frozenset({1}), phi=0.3738936916172339),
#  Relation(relata=(Effect[0,1,2,3],Effect[0,3]), purview=frozenset({1, 2}), phi=0.1577211247652166),
#  Relation(relata=(Effect[1,2,3],Effect[2,3]), purview=frozenset({2, 3}), phi=1.4707948357090543),
#  Relation(relata=(Cause[0,3],Effect[0,1,2]), purview=frozenset({1, 2}), phi=0.116003352756677),
#  Relation(relata=(Effect[1,2,3],Effect[3]), purview=frozenset({3}), phi=0.6561293724897728),
#  Relation(relata=(Cause[1],Effect[0,2]), purview=frozenset({1}), phi=0.1961656470150981),
#  Relation(relata=(Effect[0,1],Effect[0,1,2]), purview=frozenset({0, 1}), phi=1.4707948357090541),
#  Relation(relata=(Cause[0,2,3],Effect[2,3]), purview=frozenset({2}), phi=0.37389369161723407),
#  Relation(relata=(Cause[0,1],Effect[0,2,3]), purview=frozenset({1}), phi=0.2409571632861295),
#  Relation(relata=(Cause[0,2,3],Cause[2,3]), purview=frozenset({2}), phi=0.3485718560370109),
#  Relation(relata=(Effect[0,1],Cause[0,3]), purview=frozenset({1}), phi=0.06050021910372112),
#  Relation(relata=(Effect[0,1],Effect[1,2]), purview=frozenset({1}), phi=0.8045683782634601),
#  Relation(relata=(Cause[2,3],Cause[0,1,2]), purview=frozenset({2}), phi=0.23558289179339065),
#  Relation(relata=(Cause[0,1],Effect[0,1,3]), purview=frozenset({0, 1}), phi=0.7899526207821111),
#  Relation(relata=(Cause[3],Effect[3]), purview=frozenset({3}), phi=0.5203817439621854),
#  Relation(relata=(Effect[2],Effect[1,2]), purview=frozenset({2}), phi=0.7137239705010137),
#  Relation(relata=(Cause[1],Effect[0,1,2]), purview=frozenset({1}), phi=0.629285242579019),
#  Relation(relata=(Effect[1,3],Cause[2,3]), purview=frozenset({2, 3}), phi=0.5013485655544767),
#  Relation(relata=(Cause[2,3],Cause[0,3]), purview=frozenset({2}), phi=0.06050021910372112),
#  Relation(relata=(Cause[1,2,3],Effect[1,2,3]), purview=frozenset({1, 2, 3}), phi=0.8562529985412691),
#  Relation(relata=(Cause[1,2,3],Effect[2]), purview=frozenset({2}), phi=0.17715934465890198),
#  Relation(relata=(Effect[0,1],Effect[0,1,3]), purview=frozenset({0, 1}), phi=1.0581087025787774),
#  Relation(relata=(Effect[0],Effect[0,1]), purview=frozenset({0}), phi=0.6561293724897728),
#  Relation(relata=(Cause[1],Cause[0,2]), purview=frozenset({1}), phi=0.16776015858407486),
#  Relation(relata=(Effect[0,2,3],Cause[3]), purview=frozenset({3}), phi=0.4756872078760291),
#  Relation(relata=(Effect[0,1,2],Effect[2]), purview=frozenset({2}), phi=0.7137239705010137),
#  Relation(relata=(Effect[2,3],Cause[0,3]), purview=frozenset({2}), phi=0.06050021910372112),
#  Relation(relata=(Effect[0,1,2],Effect[1,2]), purview=frozenset({1, 2}), phi=1.6091367565269208),
#  Relation(relata=(Cause[1],Effect[1,2]), purview=frozenset({1}), phi=0.629285242579019),
#  Relation(relata=(Cause[0,1],Cause[0,1,2,3]), purview=frozenset({0, 1}), phi=0.1756225857962925),
#  Relation(relata=(Effect[1,3],Effect[0,1,2,3]), purview=frozenset({1, 2, 3}), phi=1.151569937816523),
#  Relation(relata=(Cause[2,3],Effect[0,1,2,3]), purview=frozenset({2, 3}), phi=0.7899526207821111),
#  Relation(relata=(Cause[1,2,3],Cause[0,1,2,3]), purview=frozenset({1, 2}), phi=0.2599402121340316),
#  Relation(relata=(Cause[0,2,3],Effect[0,1,2]), purview=frozenset({1, 2}), phi=0.5302633237693966),
#  Relation(relata=(Cause[2,3],Cause[2]), purview=frozenset({2}), phi=0.3485718560370109),
#  Relation(relata=(Effect[0,1,2],Effect[0,1,3]), purview=frozenset({0, 1, 2}), phi=1.299065865864907),
#  Relation(relata=(Cause[0,2],Effect[0,2]), purview=frozenset({1}), phi=0.16776015858407486),
#  Relation(relata=(Cause[0,2,3],Effect[1,2]), purview=frozenset({1, 2}), phi=0.5302633237693966),
#  Relation(relata=(Cause[2],Cause[0,1,2,3]), purview=frozenset({2}), phi=0.15433012402409746),
#  Relation(relata=(Cause[2],Effect[0,1,2,3]), purview=frozenset({2}), phi=0.629285242579019),
#  Relation(relata=(Effect[2],Effect[0,1,3]), purview=frozenset({2}), phi=0.2409571632861297),
#  Relation(relata=(Effect[0,1,3],Effect[1,2]), purview=frozenset({1, 2}), phi=0.823378657988878),
#  Relation(relata=(Effect[1,3],Effect[1,2]), purview=frozenset({1, 2}), phi=0.7087202350202687),
#  Relation(relata=(Effect[1,3],Effect[1,2,3]), purview=frozenset({1, 2, 3}), phi=1.151569937816523),
#  Relation(relata=(Cause[1,2,3],Cause[0,3]), purview=frozenset({1, 2}), phi=0.116003352756677),
#  Relation(relata=(Cause[0,2,3],Effect[0,1,3]), purview=frozenset({1, 2}), phi=0.3603999533918338),
#  Relation(relata=(Cause[1,2,3],Effect[1]), purview=frozenset({1}), phi=0.2355828917933908),
#  Relation(relata=(Effect[0,2,3],Cause[0,1,2]), purview=frozenset({1, 2}), phi=0.47654005507952013),
#  Relation(relata=(Cause[1,2,3],Effect[3]), purview=frozenset({3}), phi=0.1786285822145354),
#  Relation(relata=(Cause[0,1],Effect[0,1,2,3]), purview=frozenset({0, 1}), phi=0.7899526207821111),
#  Relation(relata=(Effect[1,3],Cause[0,1,2,3]), purview=frozenset({1, 2}), phi=0.26126230321719374),
#  Relation(relata=(Cause[1,3],Effect[0,2,3]), purview=frozenset({2}), phi=0.16776015858407486),
#  Relation(relata=(Cause[0,2,3],Cause[0,1,2,3]), purview=frozenset({1, 2}), phi=0.26126230321719374),
#  Relation(relata=(Cause[0,1,2,3],Effect[0,1,3]), purview=frozenset({0, 1, 2}), phi=0.3621610479246914),
#  Relation(relata=(Cause[0,1,2],Cause[0,1,3]), purview=frozenset({1, 2}), phi=0.29660213476460584),
#  Relation(relata=(Effect[1,3],Effect[0,2,3]), purview=frozenset({1, 2, 3}), phi=0.8799725130974817),
#  Relation(relata=(Cause[1,3],Effect[0,1,2]), purview=frozenset({2}), phi=0.16776015858407486),
#  Relation(relata=(Cause[1,2,3],Effect[0,2]), purview=frozenset({1, 2}), phi=0.3733249916740001),
#  Relation(relata=(Cause[1,2],Effect[1,2]), purview=frozenset({1, 2}), phi=0.9470674774522065),
#  Relation(relata=(Cause[1],Effect[0,3]), purview=frozenset({1}), phi=0.07886056238260826),
#  Relation(relata=(Cause[2,3],Effect[2,3]), purview=frozenset({2, 3}), phi=0.7899526207821111),
#  Relation(relata=(Effect[0,1,2],Cause[1,2]), purview=frozenset({1, 2}), phi=0.9470674774522065),
#  Relation(relata=(Effect[0],Cause[0,1,2]), purview=frozenset({0}), phi=0.17862858221453526),
#  Relation(relata=(Effect[0,3],Cause[1,2]), purview=frozenset({1, 2}), phi=0.1577211247652166),
#  Relation(relata=(Cause[0],Effect[0]), purview=frozenset({0}), phi=0.5203817439621854),
#  Relation(relata=(Effect[1,2,3],Cause[3]), purview=frozenset({3}), phi=0.5203817439621854),
#  Relation(relata=(Cause[0,1,2],Effect[0,1,2]), purview=frozenset({0, 1, 2}), phi=0.8562529985412689),
#  Relation(relata=(Effect[2,3],Cause[2]), purview=frozenset({2}), phi=0.629285242579019),
#  Relation(relata=(Cause[0,1],Effect[0,1]), purview=frozenset({0, 1}), phi=0.7899526207821111),
#  Relation(relata=(Effect[0],Effect[0,1,2,3]), purview=frozenset({0}), phi=0.6561293724897728),
#  Relation(relata=(Cause[2],Cause[0,1,3]), purview=frozenset({2}), phi=0.11944279010570402),
#  Relation(relata=(Cause[1,3],Effect[2,3]), purview=frozenset({2}), phi=0.16776015858407486),
#  Relation(relata=(Cause[0,1,2],Effect[1,2]), purview=frozenset({1, 2}), phi=0.5198279482519588),
#  Relation(relata=(Cause[0,1,2],Effect[2]), purview=frozenset({2}), phi=0.23558289179339065),
#  Relation(relata=(Cause[0,2,3],Effect[0,2]), purview=frozenset({1, 2}), phi=0.5302633237693966),
#  Relation(relata=(Cause[2,3],Effect[1,2]), purview=frozenset({2}), phi=0.3485718560370109),
#  Relation(relata=(Effect[0,1,2,3],Effect[0,1,2]), purview=frozenset({0, 1, 2}), phi=2.2934270330882263),
#  Relation(relata=(Effect[1,3],Effect[2]), purview=frozenset({2}), phi=0.19616564701509828),
#  Relation(relata=(Cause[0,1],Cause[0,1,3]), purview=frozenset({1}), phi=0.3485718560370109),
#  Relation(relata=(Effect[1],Effect[0,3]), purview=frozenset({1}), phi=0.07886056238260826),
#  Relation(relata=(Effect[0,2,3],Effect[2,3]), purview=frozenset({2, 3}), phi=1.0581087025787776),
#  Relation(relata=(Effect[0,2,3],Effect[0,1,2,3]), purview=frozenset({1, 2, 3}), phi=1.299065865864907),
#  Relation(relata=(Cause[1],Cause[0,1,2]), purview=frozenset({1}), phi=0.17715934465890185),
#  Relation(relata=(Effect[0,2],Effect[0,3]), purview=frozenset({1, 2}), phi=0.1577211247652166),
#  Relation(relata=(Cause[1,3],Cause[1,2]), purview=frozenset({2}), phi=0.16776015858407486),
#  Relation(relata=(Effect[0,1,2,3],Effect[0,1,3]), purview=frozenset({0, 1, 2}), phi=1.299065865864907),
#  Relation(relata=(Cause[2],Effect[0,1,2]), purview=frozenset({2}), phi=0.629285242579019),
#  Relation(relata=(Cause[0,1],Cause[0,2,3]), purview=frozenset({1}), phi=0.11944279010570406),
#  Relation(relata=(Cause[0],Effect[0,1,3]), purview=frozenset({0}), phi=0.4756872078760291),
#  Relation(relata=(Cause[0,2],Effect[1,2,3]), purview=frozenset({1}), phi=0.16776015858407486),
#  Relation(relata=(Cause[0,2],Cause[1,2]), purview=frozenset({1}), phi=0.16776015858407486),
#  Relation(relata=(Effect[2,3],Cause[0,1,3]), purview=frozenset({2}), phi=0.11944279010570402),
#  Relation(relata=(Cause[1,2,3],Cause[1,2]), purview=frozenset({1, 2}), phi=0.5198279482519591),
#  Relation(relata=(Effect[0,2],Cause[0,1,2]), purview=frozenset({0, 1, 2}), phi=0.6719250715694407),
#  Relation(relata=(Cause[0,1,2,3],Effect[2]), purview=frozenset({2}), phi=0.15433012402409746)]

# %%
ces = pyphi.big_phi.sia(subsystem,distinctions,relations)
# Out:
# Done putting relations
# Finding maximal compositional state
# Submitting tasks: 0it [00:00, ?it/s]
# Done submitting tasks
#   0%|          | 0/2 [00:00<?, ?it/s]
# Evaluating maximal compositional state

# %%
max_distintions = ces.phi_structure.distinctions
max_relations = ces.phi_structure.relations

# %%
#Plot the cause-effect structure
fig = visualize_ces.plot_ces(
    subsystem,
    sep(max_distintions),
    max_relations,
    network_name="example_ces",
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_13317/3037096652.py in <module>
#       1 #Plot the cause-effect structure
# ----> 2 fig = visualize_ces.plot_ces(
#       3     subsystem,
#       4     sep(max_distintions),
#       5     max_relations,
#
# ~/anaconda3/lib/python3.9/site-packages/visualize_pyphi/visualize_ces.py in plot_ces(subsystem, ces, relations, network_name, floor_width_scale, floor_width_scales, floor_height_scale, cause_effect_distance, base_height_scale, base_z_offset, base_width_scale, base_opacity, base_intensity, base_color, user_mechanism_coordinates, user_purview_coordinates, mechanism_labels_size, purview_labels_size, mechanism_label_position, purview_label_position, edge_size_range, state_as_lettercase, link_width_range, transparent_edges, surface_size_range, surface_colorscale, surface_opacity, axes_range, eye_coordinates, hovermode, plot_dimensions, save_plot_to_html, save_plot_to_png, show_mechanism_base, show_chains, show_links, show_mesh, show_edges, show_labels, colorcode_2_relations, show_legend, transparent_background, chain_width, fig)
#     372
#     373     # Get mechanism and purview labels
# --> 374     mechanism_labels = [
#     375         label_mechanism(
#     376             mice, bold=False, state=subsystem.state if state_as_lettercase else False,
#
# ~/anaconda3/lib/python3.9/site-packages/visualize_pyphi/visualize_ces.py in <listcomp>(.0)
#     373     # Get mechanism and purview labels
#     374     mechanism_labels = [
# --> 375         label_mechanism(
#     376             mice, bold=False, state=subsystem.state if state_as_lettercase else False,
#     377         )
#
# ~/anaconda3/lib/python3.9/site-packages/visualize_pyphi/visualize_ces.py in label_mechanism(mice, bold, state)
#      95 def label_mechanism(mice, bold=False, state=False):
#      96     return make_label(
# ---> 97         mice.mechanism, node_labels=mice.node_labels, bold=bold, state=state
#      98     )
#      99
#
# AttributeError: 'MaximallyIrreducibleCause' object has no attribute 'node_labels'
